# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./pkml.csv')

# %%
df.columns
# Out:
# Index(['method', 'uri', 'query', 'protocol', 'Accept-Language',
#        'Accept-Encoding', 'Accept', 'User-Agent', 'classification'],
#       dtype='object')

# %%
len(df[df['classification']==1])
# Out:
# 15110

# %%
len(df[df['classification']==0])
# Out:
# 35006

# %%
df.groupby('classification').size().plot(kind='bar', title='Count normal(0) and malicious(1)')
# Out:
# <AxesSubplot: title={'center': 'Count normal(0) and malicious(1)'}, xlabel='classification'>

# %%
normal=df[df['classification']==0]
malicious=df[df['classification']==1]

# %%
normal.groupby('method').size().plot(kind='bar',title='normal requests')
# Out:
# <AxesSubplot: title={'center': 'normal requests'}, xlabel='method'>

# %%
malicious.groupby('method').size().plot(kind='bar',title='malicious requests')
# Out:
# <AxesSubplot: title={'center': 'malicious requests'}, xlabel='method'>

# %%
de=pd.read_csv('./requests.csv')

# %%
df=df.append(de)
# Out:
# C:\Users\91735\AppData\Local\Temp\ipykernel_9060\2276616520.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(de)

# %%
df.groupby('classification').size().plot(kind='bar', title='Count normal(0) and malicious(1) after adding custom dataset')
# Out:
# <AxesSubplot: title={'center': 'Count normal(0) and malicious(1) after adding custom dataset'}, xlabel='classification'>

# %%
normal=df[df['classification']==0]
malicious=df[df['classification']==1]

# %%
normal.groupby('method').size().plot(kind='bar',title='normal requests after')
# Out:
# <AxesSubplot: title={'center': 'normal requests after'}, xlabel='method'>

# %%
malicious.groupby('method').size().plot(kind='bar',title='malicious requests after')
# Out:
# <AxesSubplot: title={'center': 'malicious requests after'}, xlabel='method'>
